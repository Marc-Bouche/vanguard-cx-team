# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %% [markdown]
# <h1>Data Import</h1>

# %%
client_profiles_df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_demo.txt")
client_profiles_df
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth
# 0        45105.30           6.0            9.0
# 1       110860.30           6.0            9.0
# 2        52467.79           6.0            9.0
# 3        67454.65           3.0            6.0
# 4       103671.75           0.0            3.0
# ...           ...           ...            ...
# 70604  1411062.68           5.0            5.0
# 70605   101867.07           6.0            6.0
# 70606    40745.00           3.0            3.0
# 70607   475114.69           4.0            4.0
# 70608   157498.73           7.0            7.0
#
# [70609 rows x 9 columns]

# %%
df_web_data_1 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_web_data_pt_1.txt")
df_web_data_1
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 343136    2443347  465784886_73090545671  136329900_10529659391_316129
# 343137    2443347  465784886_73090545671  136329900_10529659391_316129
# 343138    2443347  465784886_73090545671  136329900_10529659391_316129
# 343139    2443347  465784886_73090545671  136329900_10529659391_316129
# 343140    2443347  465784886_73090545671  136329900_10529659391_316129
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# 1            step_2  2017-04-17 15:26:51
# 2            step_3  2017-04-17 15:19:22
# 3            step_2  2017-04-17 15:19:13
# 4            step_3  2017-04-17 15:18:04
# ...             ...                  ...
# 343136      confirm  2017-03-31 15:15:46
# 343137       step_3  2017-03-31 15:14:53
# 343138       step_2  2017-03-31 15:12:08
# 343139       step_1  2017-03-31 15:11:37
# 343140        start  2017-03-31 15:10:47
#
# [343141 rows x 5 columns]

# %%
df_web_data_2 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_web_data_pt_2.txt")
df_web_data_2
# Out:
#         client_id             visitor_id                      visit_id  \
# 0          763412  601952081_10457207388  397475557_40440946728_419634
# 1         6019349  442094451_91531546617  154620534_35331068705_522317
# 2         6019349  442094451_91531546617  154620534_35331068705_522317
# 3         6019349  442094451_91531546617  154620534_35331068705_522317
# 4         6019349  442094451_91531546617  154620534_35331068705_522317
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0           confirm  2017-06-06 08:56:00
# 1           confirm  2017-06-01 11:59:27
# 2            step_3  2017-06-01 11:58:48
# 3            step_2  2017-06-01 11:58:08
# 4            step_1  2017-06-01 11:57:58
# ...             ...                  ...
# 412259        start  2017-05-24 18:46:10
# 412260        start  2017-05-24 18:45:29
# 412261       step_1  2017-05-24 18:44:51
# 412262        start  2017-05-24 18:44:34
# 412263        start  2017-06-03 12:17:09
#
# [412264 rows x 5 columns]

# %%
df_web_data_merged = pd.concat([df_web_data_1, df_web_data_2], axis=0)
df_web_data_merged
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# 1            step_2  2017-04-17 15:26:51
# 2            step_3  2017-04-17 15:19:22
# 3            step_2  2017-04-17 15:19:13
# 4            step_3  2017-04-17 15:18:04
# ...             ...                  ...
# 412259        start  2017-05-24 18:46:10
# 412260        start  2017-05-24 18:45:29
# 412261       step_1  2017-05-24 18:44:51
# 412262        start  2017-05-24 18:44:34
# 412263        start  2017-06-03 12:17:09
#
# [755405 rows x 5 columns]

# %%
df_web_data_merged.isnull().sum()
# Out:
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64

# %%
df_final_experiment_clients =pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_experiment_clients.txt")
df_final_experiment_clients
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [70609 rows x 2 columns]

# %% [markdown]
# <h1>Data Cleaning</h1>

# %%
client_profiles_df.shape
# Out:
# (70609, 9)

# %%
client_profiles_df.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976             6.0              73.0      60.5     U        2.0
# 1    2304905             7.0              94.0      58.0     U        2.0
# 2    1439522             5.0              64.0      32.0     U        2.0
# 3    1562045            16.0             198.0      49.0     M        2.0
# 4    5126305            12.0             145.0      33.0     F        2.0
#
#          bal  calls_6_mnth  logons_6_mnth
# 0   45105.30           6.0            9.0
# 1  110860.30           6.0            9.0
# 2   52467.79           6.0            9.0
# 3   67454.65           3.0            6.0
# 4  103671.75           0.0            3.0

# %%
client_profiles_df["gendr"].value_counts()
# Out:
# gendr
# U    24122
# M    23724
# F    22746
# X        3
# Name: count, dtype: int64

# %%
client_profiles_df["num_accts"].value_counts()
# Out:
# num_accts
# 2.0    55497
# 3.0    12529
# 4.0     2241
# 5.0      284
# 6.0       33
# 7.0        8
# 1.0        2
# 8.0        1
# Name: count, dtype: int64

# %%
client_profiles_df["calls_6_mnth"].value_counts()
# Out:
# calls_6_mnth
# 6.0    14112
# 1.0    11016
# 2.0    10252
# 3.0     8752
# 0.0     7732
# 4.0     7175
# 5.0     6627
# 7.0     4929
# Name: count, dtype: int64

# %%
client_profiles_df.isnull().sum()
# Out:
# client_id            0
# clnt_tenure_yr      14
# clnt_tenure_mnth    14
# clnt_age            15
# gendr               14
# num_accts           14
# bal                 14
# calls_6_mnth        14
# logons_6_mnth       14
# dtype: int64

# %%
# dropping rows with null values

df_client_profiles = client_profiles_df.dropna(axis=0, how="any")

# %%
# summarizing the gender column 

df_client_profiles["gendr"] = df_client_profiles["gendr"].replace("X", "U", inplace=True)
df_client_profiles
# Out:
# /var/folders/t2/40gs14tj4lg2536r26vzcyv40000gn/T/ipykernel_14376/995078205.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_client_profiles["gendr"] = df_client_profiles["gendr"].replace("X", "U", inplace=True)
# /var/folders/t2/40gs14tj4lg2536r26vzcyv40000gn/T/ipykernel_14376/995078205.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_client_profiles["gendr"] = df_client_profiles["gendr"].replace("X", "U", inplace=True)
# /var/folders/t2/40gs14tj4lg2536r26vzcyv40000gn/T/ipykernel_14376/995078205.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_client_profiles["gendr"] = df_client_profiles["gendr"].replace("X", "U", inplace=True)
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5  None        2.0
# 1        2304905             7.0              94.0      58.0  None        2.0
# 2        1439522             5.0              64.0      32.0  None        2.0
# 3        1562045            16.0             198.0      49.0  None        2.0
# 4        5126305            12.0             145.0      33.0  None        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5  None        3.0
# 70605    8981690            12.0             148.0      31.0  None        2.0
# 70606     333913            16.0             198.0      61.5  None        2.0
# 70607    1573142            21.0             255.0      68.0  None        3.0
# 70608    5602139            21.0             254.0      59.5  None        3.0
#
#               bal  calls_6_mnth  logons_6_mnth
# 0        45105.30           6.0            9.0
# 1       110860.30           6.0            9.0
# 2        52467.79           6.0            9.0
# 3        67454.65           3.0            6.0
# 4       103671.75           0.0            3.0
# ...           ...           ...            ...
# 70604  1411062.68           5.0            5.0
# 70605   101867.07           6.0            6.0
# 70606    40745.00           3.0            3.0
# 70607   475114.69           4.0            4.0
# 70608   157498.73           7.0            7.0
#
# [70594 rows x 9 columns]

# %%
sns.countplot(data=df_client_profiles, x='num_accts', palette="Set3")
# Out:
# /var/folders/t2/40gs14tj4lg2536r26vzcyv40000gn/T/ipykernel_14376/3276336683.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_client_profiles, x='num_accts', palette="Set3")
# <Axes: xlabel='num_accts', ylabel='count'>

# %%
df_client_profiles.describe().round(2)
# Out:
#         client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age  num_accts  \
# count    70594.00        70594.00          70594.00  70594.00   70594.00
# mean   5005025.75           12.05            150.66     46.44       2.26
# std    2877289.31            6.87             82.09     15.59       0.53
# min        169.00            2.00             33.00     13.50       1.00
# 25%    2519542.75            6.00             82.00     32.50       2.00
# 50%    5016973.50           11.00            136.00     47.00       2.00
# 75%    7483074.25           16.00            192.00     59.00       2.00
# max    9999839.00           62.00            749.00     96.00       8.00
#
#                bal  calls_6_mnth  logons_6_mnth
# count     70594.00      70594.00       70594.00
# mean     147446.73          3.38           5.57
# std      301510.58          2.24           2.35
# min       13789.42          0.00           1.00
# 25%       37346.60          1.00           4.00
# 50%       63334.59          3.00           5.00
# 75%      137546.12          6.00           7.00
# max    16320040.15          7.00           9.00

# %%
df_client_profiles.hist(figsize=(15, 20), bins=60, xlabelsize=10, ylabelsize=10);

# %%
# Merging Df Demographics with DF Variations

df_client_test_merged = df_client_profiles.merge(df_final_experiment_clients, how="inner", on = "client_id")
df_client_test_merged
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5  None        2.0
# 1        2304905             7.0              94.0      58.0  None        2.0
# 2        1439522             5.0              64.0      32.0  None        2.0
# 3        1562045            16.0             198.0      49.0  None        2.0
# 4        5126305            12.0             145.0      33.0  None        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70589    7993686             4.0              56.0      38.5  None        3.0
# 70590    8981690            12.0             148.0      31.0  None        2.0
# 70591     333913            16.0             198.0      61.5  None        2.0
# 70592    1573142            21.0             255.0      68.0  None        3.0
# 70593    5602139            21.0             254.0      59.5  None        3.0
#
#               bal  calls_6_mnth  logons_6_mnth Variation
# 0        45105.30           6.0            9.0      Test
# 1       110860.30           6.0            9.0   Control
# 2        52467.79           6.0            9.0      Test
# 3        67454.65           3.0            6.0      Test
# 4       103671.75           0.0            3.0   Control
# ...           ...           ...            ...       ...
# 70589  1411062.68           5.0            5.0       NaN
# 70590   101867.07           6.0            6.0       NaN
# 70591    40745.00           3.0            3.0       NaN
# 70592   475114.69           4.0            4.0       NaN
# 70593   157498.73           7.0            7.0       NaN
#
# [70594 rows x 10 columns]

# %%
df_clients_test = df_client_test_merged[df_client_test_merged["Variation"] == "Test"].reset_index(drop=True)
df_clients_test
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5  None        2.0
# 1        1439522             5.0              64.0      32.0  None        2.0
# 2        1562045            16.0             198.0      49.0  None        2.0
# 3         388801            30.0             361.0      57.5  None        5.0
# 4        8198645            15.0             189.0      54.5  None        2.0
# ...          ...             ...               ...       ...   ...        ...
# 26956     501496            23.0             281.0      35.0  None        2.0
# 26957    1780858            21.0             262.0      68.5  None        3.0
# 26958    5826160            20.0             249.0      56.5  None        2.0
# 26959    8739285            19.0             229.0      69.5  None        2.0
# 26960    7468138            18.0             222.0      61.0  None        3.0
#
#              bal  calls_6_mnth  logons_6_mnth Variation
# 0       45105.30           6.0            9.0      Test
# 1       52467.79           6.0            9.0      Test
# 2       67454.65           3.0            6.0      Test
# 3      522498.72           1.0            4.0      Test
# 4      382303.83           6.0            9.0      Test
# ...          ...           ...            ...       ...
# 26956   32529.34           0.0            3.0      Test
# 26957  372100.59           6.0            9.0      Test
# 26958   44837.16           2.0            5.0      Test
# 26959   44994.24           1.0            4.0      Test
# 26960  209278.15           0.0            3.0      Test
#
# [26961 rows x 10 columns]

# %%
df_clients_test.describe()
# Out:
#           client_id  clnt_tenure_yr  clnt_tenure_mnth      clnt_age  \
# count  2.696100e+04    26961.000000      26961.000000  26961.000000
# mean   4.999639e+06       11.982901        149.852899     47.163922
# std    2.877510e+06        6.844947         81.783390     15.514461
# min    5.550000e+02        2.000000         33.000000     17.000000
# 25%    2.516570e+06        6.000000         82.000000     33.500000
# 50%    5.025928e+06       11.000000        134.000000     47.500000
# 75%    7.470213e+06       15.000000        191.000000     59.500000
# max    9.999832e+06       55.000000        669.000000     96.000000
#
#           num_accts           bal  calls_6_mnth  logons_6_mnth
# count  26961.000000  2.696100e+04  26961.000000   26961.000000
# mean       2.249917  1.489626e+05      3.061941       6.101851
# std        0.529335  3.073737e+05      2.190590       2.177119
# min        1.000000  2.378944e+04      0.000000       3.000000
# 25%        2.000000  3.972920e+04      1.000000       4.000000
# 50%        2.000000  6.546836e+04      3.000000       6.000000
# 75%        2.000000  1.394786e+05      5.000000       8.000000
# max        7.000000  1.632004e+07      6.000000       9.000000

# %%
df_clients_test.hist(figsize=(15, 20), bins=60, xlabelsize=10, ylabelsize=10);

# %%
df_clients_control = df_client_test_merged[df_client_test_merged["Variation"] == "Control"].reset_index(drop=True)
df_clients_control
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0        2304905             7.0              94.0      58.0  None        2.0
# 1        5126305            12.0             145.0      33.0  None        2.0
# 2        3727881             5.0              71.0      30.5  None        2.0
# 3         272934             5.0              66.0      58.5  None        2.0
# 4         285619            30.0             369.0      67.5  None        2.0
# ...          ...             ...               ...       ...   ...        ...
# 23521    6662941             7.0              84.0      36.0  None        2.0
# 23522    2787512            23.0             283.0      48.0  None        3.0
# 23523    9932367            23.0             280.0      57.0  None        2.0
# 23524    4079649            23.0             276.0      62.5  None        3.0
# 23525    6967120            21.0             260.0      68.5  None        3.0
#
#               bal  calls_6_mnth  logons_6_mnth Variation
# 0       110860.30           6.0            9.0   Control
# 1       103671.75           0.0            3.0   Control
# 2        23915.60           0.0            3.0   Control
# 3        27021.42           2.0            5.0   Control
# 4       299388.72           3.0            6.0   Control
# ...           ...           ...            ...       ...
# 23521    83101.84           4.0            7.0   Control
# 23522   123618.60           1.0            4.0   Control
# 23523    94466.55           6.0            9.0   Control
# 23524    57575.28           4.0            7.0   Control
# 23525  4279873.38           6.0            9.0   Control
#
# [23526 rows x 10 columns]

# %%
df_clients_control.describe().round(2)
# Out:
#         client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age  num_accts  \
# count    23526.00        23526.00          23526.00  23526.00   23526.00
# mean   5013676.13           12.09            151.06     47.50       2.26
# std    2877413.56            6.88             82.13     15.52       0.54
# min       1028.00            2.00             33.00     17.00       2.00
# 25%    2515177.00            6.00             82.00     33.50       2.00
# 50%    5023832.50           11.00            137.00     48.50       2.00
# 75%    7483638.50           16.00            192.00     60.00       2.00
# max    9998921.00           55.00            669.00     96.00       7.00
#
#               bal  calls_6_mnth  logons_6_mnth
# count    23526.00      23526.00       23526.00
# mean    150151.90          3.13           6.17
# std     295812.41          2.18           2.17
# min      23789.61          0.00           3.00
# 25%      40122.95          1.00           4.00
# 50%      66031.45          3.00           6.00
# 75%     140615.63          5.00           8.00
# max    8292996.21          6.00           9.00

# %%
df_clients_control.hist(figsize=(15, 20), bins=60, xlabelsize=10, ylabelsize=10);

# %%
df_clients_no_test = df_client_test_merged[df_client_test_merged["Variation"].isnull()== True].reset_index(drop=True)
df_clients_no_test
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         414870             6.0              80.0      57.0  None        2.0
# 1        1047811             9.0             118.0      30.0  None        2.0
# 2        6090170             5.0              62.0      28.0  None        2.0
# 3         706631            16.0             193.0      56.0  None        2.0
# 4        6844077            16.0             196.0      48.5  None        2.0
# ...          ...             ...               ...       ...   ...        ...
# 20102    7993686             4.0              56.0      38.5  None        3.0
# 20103    8981690            12.0             148.0      31.0  None        2.0
# 20104     333913            16.0             198.0      61.5  None        2.0
# 20105    1573142            21.0             255.0      68.0  None        3.0
# 20106    5602139            21.0             254.0      59.5  None        3.0
#
#               bal  calls_6_mnth  logons_6_mnth Variation
# 0       492304.33           5.0            5.0       NaN
# 1        27085.88           5.0            5.0       NaN
# 2        39855.30           4.0            4.0       NaN
# 3        52298.64           5.0            5.0       NaN
# 4       518763.48           7.0            7.0       NaN
# ...           ...           ...            ...       ...
# 20102  1411062.68           5.0            5.0       NaN
# 20103   101867.07           6.0            6.0       NaN
# 20104    40745.00           3.0            3.0       NaN
# 20105   475114.69           4.0            4.0       NaN
# 20106   157498.73           7.0            7.0       NaN
#
# [20107 rows x 10 columns]

# %%
df_clients_no_test.describe().round(2)
# Out:
#         client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age  num_accts  \
# count    20107.00        20107.00          20107.00  20107.00   20107.00
# mean   5002128.07           12.11            151.27     44.24       2.26
# std    2876968.03            6.90             82.45     15.56       0.54
# min        169.00            2.00             33.00     13.50       1.00
# 25%    2532094.50            6.00             82.00     30.50       2.00
# 50%    4998573.00           11.00            138.00     45.00       2.00
# 75%    7493638.50           16.00            193.00     56.50       2.00
# max    9999839.00           62.00            749.00     92.50       8.00
#
#                bal  calls_6_mnth  logons_6_mnth
# count     20107.00      20107.00       20107.00
# mean     142248.96          4.11           4.15
# std      300124.15          2.19           2.18
# min       13789.42          1.00           1.00
# 25%       30147.72          2.00           2.00
# 50%       56338.10          4.00           4.00
# 75%      130512.66          6.00           6.00
# max    12838418.01          7.00           7.00

# %%
df_clients_no_test.hist(figsize=(15, 20), bins=60, xlabelsize=10, ylabelsize=10);

# %% [markdown]
# ### Who are the primary clients using this online process?

# %%
#

# %%
client_profiles_df["gendr"].value_counts()
# Out:
# gendr
# U    24122
# M    23724
# F    22746
# X        3
# Name: count, dtype: int64

# %% [markdown]
# ### Are the primary clients younger or older?

# %%
#The clients average age is 45 years old.
#The most represented age is 51 years old.

# if age > 40 = 'young'
# if age < 40 = 'old'
# then our primary clients are, in average, old.

# %%
#Age Calucaltion

# %%
df_clients_no_test['clnt_age'].mean()
# Out:
# 44.23877256676779

# %%
df_clients_no_test['clnt_age'].median()
# Out:
# 45.0

# %%
df_clients_no_test['clnt_age'].mode()
# Out:
# 0    51.5
# Name: clnt_age, dtype: float64

# %% [markdown]
# ### Are the primary clients new or long-standing?

# %%
#The clients average standing is 151 months (aka 12 years and 7 months) in terms of mean.
#The clients average standing is 138 months (aka 11 years and 6 months) in terms of median.
#The most represented standing is, on the other hand, only 58 months (4 years and 10 months) which may indicate an uneven distribution

# if new-standing > 60 months (aka 5 years)
# if long-stamding < 60 months (aka 5 years)
# them our primary clients are, in average, long-standing.

# %%
#Standing Calucaltion

# %%
df_clients_no_test['clnt_tenure_mnth'].mean()
# Out:
# 151.2717461580544

# %%
df_clients_no_test['clnt_tenure_mnth'].median()
# Out:
# 138.0

# %%
df_clients_no_test['clnt_tenure_mnth'].mode()
# Out:
# 0    58.0
# Name: clnt_tenure_mnth, dtype: float64
